# %%
# Imoports
import pandas as pd
import sqlite3

# %%
# Connect SQLite database.
db_conn = sqlite3.connect("SuperstoreDB/superstore.db")

# %% [markdown]
# # Questions:

# %%
# 1. What is the category generating the maximum sales revenue?
pd.read_sql(
    """
    SELECT Category, SUM(Sales)/100.0 AS "Sales Revenue ($)"
    FROM OrdersDetails
    JOIN Products ON OrdersDetails.ProductID = Products.ProductID
    GROUP BY Category
    ORDER BY "Sales Revenue ($)" DESC
    LIMIT 1;
    """, db_conn)
# Out:
#      Category  Sales Revenue ($)
# 0  Technology          836149.37

# %%
# What about the profit in this category?
pd.read_sql(
    """
    SELECT Category, SUM(Profit)/100.0 AS "Profit ($)"
    FROM OrdersDetails
    JOIN Products ON OrdersDetails.ProductID = Products.ProductID
    GROUP BY Category
    HAVING Category IN (
        SELECT Category
        FROM OrdersDetails
        JOIN Products ON OrdersDetails.ProductID = Products.ProductID
        GROUP BY Category
        ORDER BY SUM(Sales) DESC
        LIMIT 1
    );
    """, db_conn)
# Out:
#      Category  Profit ($)
# 0  Technology   145448.15

# %%
# Are they making a loss in any categories?
# Show the list, so we can see.
pd.read_sql(
    """
    SELECT Category, SUM(Profit)/100.0 AS "Profit ($)"
    FROM OrdersDetails
    JOIN Products ON OrdersDetails.ProductID = Products.ProductID
    GROUP BY Category
    ORDER BY "Profit ($)" DESC;
    """, db_conn)
# Out:
#           Category  Profit ($)
# 0       Technology   145448.15
# 1  Office Supplies   122472.33
# 2        Furniture    18448.03

# %%
# Are they making a loss in any categories?
# Displays only categories with negative Profit.
pd.read_sql(
    """
    SELECT Category, SUM(Profit)/100.0 AS "Profit ($)"
    FROM OrdersDetails
    JOIN Products ON OrdersDetails.ProductID = Products.ProductID
    GROUP BY Category
    HAVING "Profit ($)" < 0
    """, db_conn)
# Out:
# Empty DataFrame
# Columns: [Category, Profit ($)]
# Index: []

# %%
# No, since there is no negative Profit anywhere.

# %%
# Is it also true for sub-categories?
# Show the list, so we can see.
pd.read_sql(
    """
    SELECT SubCategory, SUM(Profit)/100.0 AS "Profit ($)"
    FROM OrdersDetails
    JOIN Products ON OrdersDetails.ProductID = Products.ProductID
    GROUP BY SubCategory
    ORDER BY SUM(Profit);
    """, db_conn)
# Out:
#     SubCategory  Profit ($)
# 0        Tables   -17725.10
# 1     Bookcases    -3472.64
# 2      Supplies    -1189.74
# 3     Fasteners      948.67
# 4      Machines     3384.66
# 5        Labels     5544.73
# 6           Art     6523.99
# 7     Envelopes     6963.07
# 8   Furnishings    13056.10
# 9    Appliances    18136.42
# 10      Storage    21276.24
# 11       Chairs    26589.67
# 12      Binders    30220.59
# 13        Paper    34048.36
# 14  Accessories    41933.83
# 15       Phones    44512.21
# 16      Copiers    55617.45

# %%
# Is it also true for sub-categories?
# Displays only sub-categories with negative Profit.
pd.read_sql(
    """
    SELECT SubCategory, SUM(Profit)/100.0 AS "Profit ($)"
    FROM OrdersDetails
    JOIN Products ON OrdersDetails.ProductID = Products.ProductID
    GROUP BY SubCategory
    HAVING "Profit ($)" < 0
    """, db_conn)
# Out:
#   SubCategory  Profit ($)
# 0   Bookcases    -3472.64
# 1    Supplies    -1189.74
# 2      Tables   -17725.10

# %%
# Looks like some sub-categories do bring loses.

# %%
# 2. What are 5 states generating the maximum and minimum sales revenue?
states_by_sales = pd.read_sql(
    """
    SELECT State, SUM(Sales)/100.0 AS "Sales ($)"
    FROM OrdersDetails
    JOIN Orders ON OrdersDetails.OrderID = Orders.OrderID
    JOIN Addresses ON Orders.AddressID = Addresses.AddressID
    GROUP BY State
    ORDER BY SUM(Sales) DESC
    """, db_conn)

display(states_by_sales.head(5))
display(states_by_sales.tail(5))
# Out:
#           State  Sales ($)
# 0    California  457683.90
# 1      New York  310874.30
# 2         Texas  170184.17
# 3    Washington  138640.40
# 4  Pennsylvania  116509.53
#             State  Sales ($)
# 44        Wyoming    1603.13
# 45   South Dakota    1315.56
# 46          Maine    1270.53
# 47  West Virginia    1209.82
# 48   North Dakota     919.91

# %%
# 3. What are the 3 products in each product segment with the highest sales?
# I assume by product segment, Sub-Category is meant.
pd.read_sql(
    """
    SELECT *
    FROM (
        SELECT *,
        RANK() OVER  (
            PARTITION BY SubCategory
            ORDER BY "SalesSum ($)" DESC
        ) AS SalesRank
        FROM
        (
            SELECT Products.ProductID, ProductName, SUM(Sales)/100.0 AS "SalesSum ($)", SubCategory
            FROM OrdersDetails
            JOIN Products ON OrdersDetails.ProductID = Products.ProductID
            GROUP BY Products.ProductID
        )
    )
    WHERE SalesRank <= 3
    """, db_conn)
# Out:
#           ProductID                                        ProductName  \
# 0   TEC-AC-10003033  Plantronics CS510 - Over-the-Head monaural Wir...
# 1   TEC-AC-10004995                 Logitech P710e Mobile Speakerphone
# 2   TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless He...
# 3   OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleane...
# 4   OFF-AP-10002651                Hoover Upright Vacuum With Dirt Cup
# 5   OFF-AP-10000275  Sanyo Counter Height Refrigerator with Crisper...
# 6   OFF-AR-10000380    Hunt PowerHouse Electric Pencil Sharpener, Blue
# 7   OFF-AR-10002135  Boston Heavy-Duty Trimline Electric Pencil Sha...
# 8   OFF-AR-10002671  Hunt BOSTON Model 1606 High-Volume Electric Pe...
# 9   OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 10  OFF-BI-10001359         GBC DocuBind TL300 Electric Binding System
# 11  OFF-BI-10000545   GBC Ibimaster 500 Manual ProClick Binding System
# 12  FUR-BO-10004834  Riverside Palais Royal Lawyers Bookcase, Royal...
# 13  FUR-BO-10002213              DMI Eclipse Executive Suite Bookcases
# 14  FUR-BO-10002545  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...
# 15  FUR-CH-10002024       HON 5400 Series Task Chairs for Big and Tall
# 16  FUR-CH-10001215      Global Troy Executive Leather Low-Back Tilter
# 17  FUR-CH-10004287                           SAFCO Arco Folding Chair
# 18  TEC-CO-10004722              Canon imageCLASS 2200 Advanced Copier
# 19  TEC-CO-10001449               Hewlett Packard LaserJet 3310 Copier
# 20  TEC-CO-10003763                 Canon PC1060 Personal Laser Copier
# 21  OFF-EN-10000056                        Cameo Buff Policy Envelopes
# 22  OFF-EN-10003001  Ames Color-File Green Diamond Border X-ray Mai...
# 23  OFF-EN-10002230                                  Airmail Envelopes
# 24  OFF-FA-10004854  Vinyl Coated Wire Paper Clips in Organizer Box...
# 25  OFF-FA-10002280                       Advantus Plastic Paper Clips
# 26  OFF-FA-10001883          Alliance Super-Size Bands, Assorted Sizes
# 27  FUR-FU-10000576  Luxo Professional Fluorescent Magnifier Lamp w...
# 28  FUR-FU-10001468               Tenex Antistatic Computer Chair Mats
# 29  FUR-FU-10003664  Electrix Architect's Clamp-On Swing Arm Lamp, ...
# 30  OFF-LA-10003930  Dot Matrix Printer Tape Reel Labels, White, 50...
# 31  OFF-LA-10003510  Avery 4027 File Folder Labels for Dot Matrix P...
# 32  OFF-LA-10002762                                          Avery 485
# 33  TEC-MA-10002412  Cisco TelePresence System EX90 Videoconferenci...
# 34  TEC-MA-10001127  HP Designjet T520 Inkjet Large Format Printer ...
# 35  TEC-MA-10000822          Lexmark MX611dhe Monochrome Laser Printer
# 36  OFF-PA-10000994                                         Xerox 1915
# 37  OFF-PA-10004359                 Multicolor Computer Printout Paper
# 38  OFF-PA-10000418                                          Xerox 189
# 39  TEC-PH-10001459                            Samsung Galaxy Mega 6.3
# 40  TEC-PH-10002885                                     Apple iPhone 5
# 41  TEC-PH-10001817           Wilson Electronics DB Pro Signal Booster
# 42  OFF-ST-10000078              Tennsco 6- and 18-Compartment Lockers
# 43  OFF-ST-10003716                        Tennsco Double-Tier Lockers
# 44  OFF-ST-10004459                        Tennsco Single-Tier Lockers
# 45  OFF-SU-10000151        High Speed Automatic Electric Letter Opener
# 46  OFF-SU-10002881  Martin Yale Chadless Opener Electric Letter Op...
# 47  OFF-SU-10000157           Compact Automatic Electric Letter Opener
# 48  FUR-TA-10003473         Bretford Rectangular Conference Table Tops
# 49  FUR-TA-10000198  Chromcraft Bull-Nose Wood Oval Conference Tabl...
# 50  FUR-TA-10001889  Bush Advantage Collection Racetrack Conference...
#
#     SalesSum ($)  SubCategory  SalesRank
# 0       10822.34  Accessories          1
# 1       10196.59  Accessories          2
# 2        9367.28  Accessories          3
# 3       11304.42   Appliances          1
# 4        6832.88   Appliances          2
# 5        5906.52   Appliances          3
# 6        1617.90          Art          1
# 7        1166.44          Art          2
# 8        1113.02          Art          3
# 9       27453.36      Binders          1
# 10      19823.46      Binders          2
# 11      19024.46      Binders          3
# 12      15610.94    Bookcases          1
# 13      11046.59    Bookcases          2
# 14       7539.70    Bookcases          3
# 15      21870.55       Chairs          1
# 16      12975.34       Chairs          2
# 17      11572.78       Chairs          3
# 18      61599.81      Copiers          1
# 19      18839.67      Copiers          2
# 20      11619.83      Copiers          3
# 21       1555.72    Envelopes          1
# 22       1360.47    Envelopes          2
# 23       1359.65    Envelopes          3
# 24        296.17    Fasteners          1
# 25        225.00    Fasteners          2
# 26        197.61    Fasteners          3
# 27       3861.05  Furnishings          1
# 28       3316.98  Furnishings          2
# 29       2863.80  Furnishings          3
# 30       3322.87       Labels          1
# 31       1233.39       Labels          2
# 32        639.02       Labels          3
# 33      22638.48     Machines          1
# 34      18374.89     Machines          2
# 35      16829.89     Machines          3
# 36       2789.01        Paper          1
# 37       1887.30        Paper          2
# 38       1782.45        Paper          3
# 39      13943.65       Phones          1
# 40      12996.58       Phones          2
# 41       8878.37       Phones          3
# 42      10924.99      Storage          1
# 43       9630.82      Storage          2
# 44       9158.29      Storage          3
# 45      17030.31     Supplies          1
# 46      16656.18     Supplies          2
# 47       2982.74     Supplies          3
# 48      12995.25       Tables          1
# 49       9917.62       Tables          2
# 50       9544.71       Tables          3

# %%
# Are they the 3 most profitable products as well?

# %%
# Check the 3 most profitable products for each SubCategory.
pd.read_sql(
    """
    SELECT *
    FROM (
        SELECT *,
        RANK() OVER  (
            PARTITION BY SubCategory
            ORDER BY "ProfitSum ($)" DESC
        ) AS ProfitRank
        FROM
        (
            SELECT Products.ProductID, ProductName, SUM(Profit)/100.0 AS "ProfitSum ($)", SubCategory
            FROM OrdersDetails
            JOIN Products ON OrdersDetails.ProductID = Products.ProductID
            GROUP BY Products.ProductID
        )
    )
    WHERE ProfitRank <= 3
    """, db_conn)
# Out:
#           ProductID                                        ProductName  \
# 0   TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless He...
# 1   TEC-AC-10003033  Plantronics CS510 - Over-the-Head monaural Wir...
# 2   TEC-AC-10003870  Logitech Z-906 Speaker sys - home theater - 5....
# 3   OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleane...
# 4   OFF-AP-10000275  Sanyo Counter Height Refrigerator with Crisper...
# 5   OFF-AP-10003057  Honeywell Enviracaire Portable HEPA Air Cleane...
# 6   OFF-AR-10000380    Hunt PowerHouse Electric Pencil Sharpener, Blue
# 7   OFF-AR-10002135  Boston Heavy-Duty Trimline Electric Pencil Sha...
# 8   OFF-AR-10001953  Boston 1645 Deluxe Heavier-Duty Electric Penci...
# 9   OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 10  OFF-BI-10001120               Ibico EPK-21 Electric Binding System
# 11  OFF-BI-10003925        Fellowes PB300 Plastic Comb Binding Machine
# 12  FUR-BO-10002545  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...
# 13  FUR-BO-10004695  O'Sullivan 2-Door Barrister Bookcase in Odessa...
# 14  FUR-BO-10002916  Rush Hierlooms Collection 1" Thick Stackable B...
# 15  FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 16  FUR-CH-10004063            Global Deluxe High-Back Manager's Chair
# 17  FUR-CH-10002320                         Hon Pagoda Stacking Chairs
# 18  TEC-CO-10004722              Canon imageCLASS 2200 Advanced Copier
# 19  TEC-CO-10001449               Hewlett Packard LaserJet 3310 Copier
# 20  TEC-CO-10003763                 Canon PC1060 Personal Laser Copier
# 21  OFF-EN-10000056                        Cameo Buff Policy Envelopes
# 22  OFF-EN-10003296  Tyvek Side-Opening Peel & Seel Expanding Envel...
# 23  OFF-EN-10003001  Ames Color-File Green Diamond Border X-ray Mai...
# 24  OFF-FA-10004854  Vinyl Coated Wire Paper Clips in Organizer Box...
# 25  OFF-FA-10002280                       Advantus Plastic Paper Clips
# 26  OFF-FA-10003495                                            Staples
# 27  FUR-FU-10002937  GE 48" Fluorescent Tube, Cool White Energy Sav...
# 28  FUR-FU-10003664  Electrix Architect's Clamp-On Swing Arm Lamp, ...
# 29  FUR-FU-10004665  3M Polarizing Task Lamp with Clamp Arm, Light ...
# 30  OFF-LA-10003930  Dot Matrix Printer Tape Reel Labels, White, 50...
# 31  OFF-LA-10003510  Avery 4027 File Folder Labels for Dot Matrix P...
# 32  OFF-LA-10002762                                          Avery 485
# 33  TEC-MA-10001127  HP Designjet T520 Inkjet Large Format Printer ...
# 34  TEC-MA-10003979                  Ativa V4110MDD Micro-Cut Shredder
# 35  TEC-MA-10001047   3D Systems Cube Printer, 2nd Generation, Magenta
# 36  OFF-PA-10000994                                         Xerox 1915
# 37  OFF-PA-10004359                 Multicolor Computer Printout Paper
# 38  OFF-PA-10005001                                         Xerox 1908
# 39  TEC-PH-10001459                            Samsung Galaxy Mega 6.3
# 40  TEC-PH-10002885                                     Apple iPhone 5
# 41  TEC-PH-10000984                               Panasonic KX-TG9471B
# 42  OFF-ST-10001490                     Hot File 7-Pocket, Floor Stand
# 43  OFF-ST-10003208                 Adjustable Depth Letter/Legal Cart
# 44  OFF-ST-10002615              Dual Level, Single-Width Filing Carts
# 45  OFF-SU-10002573              Acme 10" Easy Grip Assistive Scissors
# 46  OFF-SU-10000898  Acme Hot Forged Carbon Steel Scissors with Nic...
# 47  OFF-SU-10001218                          Fiskars Softgrip Scissors
# 48  FUR-TA-10001307  SAFCO PlanMaster Heigh-Adjustable Drafting Tab...
# 49  FUR-TA-10004619                     Hon Non-Folding Utility Tables
# 50  FUR-TA-10003569      Bretford CR8500 Series Meeting Room Furniture
#
#     ProfitSum ($)  SubCategory  ProfitRank
# 0         3696.25  Accessories           1
# 1         3084.98  Accessories           2
# 2         2243.92  Accessories           3
# 3         3246.98   Appliances           1
# 4         1653.81   Appliances           2
# 5         1503.51   Appliances           3
# 6          448.11          Art           1
# 7          310.87          Art           2
# 8          206.23          Art           3
# 9         7753.01      Binders           1
# 10        3345.28      Binders           2
# 11        2518.04      Binders           3
# 12         780.31    Bookcases           1
# 13         566.43    Bookcases           2
# 14         410.32    Bookcases           3
# 15        1927.40       Chairs           1
# 16        1558.59       Chairs           2
# 17        1540.69       Chairs           3
# 18       25199.90      Copiers           1
# 19        6983.84      Copiers           2
# 20        4570.91      Copiers           3
# 21         632.22    Envelopes           1
# 22         570.00    Envelopes           2
# 23         559.30    Envelopes           3
# 24         119.69    Fasteners           1
# 25         102.80    Fasteners           2
# 26          85.68    Fasteners           3
# 27        1260.20  Furnishings           1
# 28         627.16  Furnishings           2
# 29         569.80  Furnishings           3
# 30        1517.85       Labels           1
# 31         524.44       Labels           2
# 32         300.30       Labels           3
# 33        4094.97     Machines           1
# 34        3772.94     Machines           2
# 35        3717.96     Machines           3
# 36        1262.34        Paper           1
# 37         851.36        Paper           2
# 38         799.38        Paper           3
# 39        1822.73       Phones           1
# 40        1611.56       Phones           2
# 41        1168.06       Phones           3
# 42        2016.65      Storage           1
# 43        1932.51      Storage           2
# 44        1640.49      Storage           3
# 45         129.67     Supplies           1
# 46         103.38     Supplies           2
# 47          86.05     Supplies           3
# 48         608.04       Tables           1
# 49         541.64       Tables           2
# 50         461.13       Tables           3

# %%
# Compare the tables side to side.
pd.read_sql(
    """
    SELECT * FROM (
        SELECT *
        FROM (
            SELECT *,
            RANK() OVER  (
                PARTITION BY SubCategory
                ORDER BY "SalesSum ($)" DESC
            ) AS SalesRank
            FROM
            (
                SELECT Products.ProductID, ProductName, SUM(Sales)/100.0 AS "SalesSum ($)", SubCategory
                FROM OrdersDetails
                JOIN Products ON OrdersDetails.ProductID = Products.ProductID
                GROUP BY Products.ProductID
            )
        )
        WHERE SalesRank <= 3) AS SalesTable
    JOIN (
        SELECT *
        FROM (
            SELECT *,
            RANK() OVER  (
                PARTITION BY SubCategory
                ORDER BY "ProfitSum ($)" DESC
            ) AS ProfitRank
            FROM
            (
                SELECT Products.ProductID, ProductName, SUM(Profit)/100.0 AS "ProfitSum ($)", SubCategory
                FROM OrdersDetails
                JOIN Products ON OrdersDetails.ProductID = Products.ProductID
                GROUP BY Products.ProductID
            )
        )
        WHERE ProfitRank <= 3) AS ProfitTable
    ON (SalesTable.SubCategory = ProfitTable.SubCategory) AND (SalesTable.SalesRank = ProfitTable.ProfitRank)
    """, db_conn)
# Out:
#           ProductID                                        ProductName  \
# 0   TEC-AC-10003033  Plantronics CS510 - Over-the-Head monaural Wir...
# 1   TEC-AC-10004995                 Logitech P710e Mobile Speakerphone
# 2   TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless He...
# 3   OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleane...
# 4   OFF-AP-10002651                Hoover Upright Vacuum With Dirt Cup
# 5   OFF-AP-10000275  Sanyo Counter Height Refrigerator with Crisper...
# 6   OFF-AR-10000380    Hunt PowerHouse Electric Pencil Sharpener, Blue
# 7   OFF-AR-10002135  Boston Heavy-Duty Trimline Electric Pencil Sha...
# 8   OFF-AR-10002671  Hunt BOSTON Model 1606 High-Volume Electric Pe...
# 9   OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 10  OFF-BI-10001359         GBC DocuBind TL300 Electric Binding System
# 11  OFF-BI-10000545   GBC Ibimaster 500 Manual ProClick Binding System
# 12  FUR-BO-10004834  Riverside Palais Royal Lawyers Bookcase, Royal...
# 13  FUR-BO-10002213              DMI Eclipse Executive Suite Bookcases
# 14  FUR-BO-10002545  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...
# 15  FUR-CH-10002024       HON 5400 Series Task Chairs for Big and Tall
# 16  FUR-CH-10001215      Global Troy Executive Leather Low-Back Tilter
# 17  FUR-CH-10004287                           SAFCO Arco Folding Chair
# 18  TEC-CO-10004722              Canon imageCLASS 2200 Advanced Copier
# 19  TEC-CO-10001449               Hewlett Packard LaserJet 3310 Copier
# 20  TEC-CO-10003763                 Canon PC1060 Personal Laser Copier
# 21  OFF-EN-10000056                        Cameo Buff Policy Envelopes
# 22  OFF-EN-10003001  Ames Color-File Green Diamond Border X-ray Mai...
# 23  OFF-EN-10002230                                  Airmail Envelopes
# 24  OFF-FA-10004854  Vinyl Coated Wire Paper Clips in Organizer Box...
# 25  OFF-FA-10002280                       Advantus Plastic Paper Clips
# 26  OFF-FA-10001883          Alliance Super-Size Bands, Assorted Sizes
# 27  FUR-FU-10000576  Luxo Professional Fluorescent Magnifier Lamp w...
# 28  FUR-FU-10001468               Tenex Antistatic Computer Chair Mats
# 29  FUR-FU-10003664  Electrix Architect's Clamp-On Swing Arm Lamp, ...
# 30  OFF-LA-10003930  Dot Matrix Printer Tape Reel Labels, White, 50...
# 31  OFF-LA-10003510  Avery 4027 File Folder Labels for Dot Matrix P...
# 32  OFF-LA-10002762                                          Avery 485
# 33  TEC-MA-10002412  Cisco TelePresence System EX90 Videoconferenci...
# 34  TEC-MA-10001127  HP Designjet T520 Inkjet Large Format Printer ...
# 35  TEC-MA-10000822          Lexmark MX611dhe Monochrome Laser Printer
# 36  OFF-PA-10000994                                         Xerox 1915
# 37  OFF-PA-10004359                 Multicolor Computer Printout Paper
# 38  OFF-PA-10000418                                          Xerox 189
# 39  TEC-PH-10001459                            Samsung Galaxy Mega 6.3
# 40  TEC-PH-10002885                                     Apple iPhone 5
# 41  TEC-PH-10001817           Wilson Electronics DB Pro Signal Booster
# 42  OFF-ST-10000078              Tennsco 6- and 18-Compartment Lockers
# 43  OFF-ST-10003716                        Tennsco Double-Tier Lockers
# 44  OFF-ST-10004459                        Tennsco Single-Tier Lockers
# 45  OFF-SU-10000151        High Speed Automatic Electric Letter Opener
# 46  OFF-SU-10002881  Martin Yale Chadless Opener Electric Letter Op...
# 47  OFF-SU-10000157           Compact Automatic Electric Letter Opener
# 48  FUR-TA-10003473         Bretford Rectangular Conference Table Tops
# 49  FUR-TA-10000198  Chromcraft Bull-Nose Wood Oval Conference Tabl...
# 50  FUR-TA-10001889  Bush Advantage Collection Racetrack Conference...
#
#     SalesSum ($)  SubCategory  SalesRank        ProductID  \
# 0       10822.34  Accessories          1  TEC-AC-10002049
# 1       10196.59  Accessories          2  TEC-AC-10003033
# 2        9367.28  Accessories          3  TEC-AC-10003870
# 3       11304.42   Appliances          1  OFF-AP-10002945
# 4        6832.88   Appliances          2  OFF-AP-10000275
# 5        5906.52   Appliances          3  OFF-AP-10003057
# 6        1617.90          Art          1  OFF-AR-10000380
# 7        1166.44          Art          2  OFF-AR-10002135
# 8        1113.02          Art          3  OFF-AR-10001953
# 9       27453.36      Binders          1  OFF-BI-10003527
# 10      19823.46      Binders          2  OFF-BI-10001120
# 11      19024.46      Binders          3  OFF-BI-10003925
# 12      15610.94    Bookcases          1  FUR-BO-10002545
# 13      11046.59    Bookcases          2  FUR-BO-10004695
# 14       7539.70    Bookcases          3  FUR-BO-10002916
# 15      21870.55       Chairs          1  FUR-CH-10000454
# 16      12975.34       Chairs          2  FUR-CH-10004063
# 17      11572.78       Chairs          3  FUR-CH-10002320
# 18      61599.81      Copiers          1  TEC-CO-10004722
# 19      18839.67      Copiers          2  TEC-CO-10001449
# 20      11619.83      Copiers          3  TEC-CO-10003763
# 21       1555.72    Envelopes          1  OFF-EN-10000056
# 22       1360.47    Envelopes          2  OFF-EN-10003296
# 23       1359.65    Envelopes          3  OFF-EN-10003001
# 24        296.17    Fasteners          1  OFF-FA-10004854
# 25        225.00    Fasteners          2  OFF-FA-10002280
# 26        197.61    Fasteners          3  OFF-FA-10003495
# 27       3861.05  Furnishings          1  FUR-FU-10002937
# 28       3316.98  Furnishings          2  FUR-FU-10003664
# 29       2863.80  Furnishings          3  FUR-FU-10004665
# 30       3322.87       Labels          1  OFF-LA-10003930
# 31       1233.39       Labels          2  OFF-LA-10003510
# 32        639.02       Labels          3  OFF-LA-10002762
# 33      22638.48     Machines          1  TEC-MA-10001127
# 34      18374.89     Machines          2  TEC-MA-10003979
# 35      16829.89     Machines          3  TEC-MA-10001047
# 36       2789.01        Paper          1  OFF-PA-10000994
# 37       1887.30        Paper          2  OFF-PA-10004359
# 38       1782.45        Paper          3  OFF-PA-10005001
# 39      13943.65       Phones          1  TEC-PH-10001459
# 40      12996.58       Phones          2  TEC-PH-10002885
# 41       8878.37       Phones          3  TEC-PH-10000984
# 42      10924.99      Storage          1  OFF-ST-10001490
# 43       9630.82      Storage          2  OFF-ST-10003208
# 44       9158.29      Storage          3  OFF-ST-10002615
# 45      17030.31     Supplies          1  OFF-SU-10002573
# 46      16656.18     Supplies          2  OFF-SU-10000898
# 47       2982.74     Supplies          3  OFF-SU-10001218
# 48      12995.25       Tables          1  FUR-TA-10001307
# 49       9917.62       Tables          2  FUR-TA-10004619
# 50       9544.71       Tables          3  FUR-TA-10003569
#
#                                           ProductName  ProfitSum ($)  \
# 0   Plantronics Savi W720 Multi-Device Wireless He...        3696.25
# 1   Plantronics CS510 - Over-the-Head monaural Wir...        3084.98
# 2   Logitech Z-906 Speaker sys - home theater - 5....        2243.92
# 3   Honeywell Enviracaire Portable HEPA Air Cleane...        3246.98
# 4   Sanyo Counter Height Refrigerator with Crisper...        1653.81
# 5   Honeywell Enviracaire Portable HEPA Air Cleane...        1503.51
# 6     Hunt PowerHouse Electric Pencil Sharpener, Blue         448.11
# 7   Boston Heavy-Duty Trimline Electric Pencil Sha...         310.87
# 8   Boston 1645 Deluxe Heavier-Duty Electric Penci...         206.23
# 9   Fellowes PB500 Electric Punch Plastic Comb Bin...        7753.01
# 10               Ibico EPK-21 Electric Binding System        3345.28
# 11        Fellowes PB300 Plastic Comb Binding Machine        2518.04
# 12  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...         780.31
# 13  O'Sullivan 2-Door Barrister Bookcase in Odessa...         566.43
# 14  Rush Hierlooms Collection 1" Thick Stackable B...         410.32
# 15  Hon Deluxe Fabric Upholstered Stacking Chairs,...        1927.40
# 16            Global Deluxe High-Back Manager's Chair        1558.59
# 17                         Hon Pagoda Stacking Chairs        1540.69
# 18              Canon imageCLASS 2200 Advanced Copier       25199.90
# 19               Hewlett Packard LaserJet 3310 Copier        6983.84
# 20                 Canon PC1060 Personal Laser Copier        4570.91
# 21                        Cameo Buff Policy Envelopes         632.22
# 22  Tyvek Side-Opening Peel & Seel Expanding Envel...         570.00
# 23  Ames Color-File Green Diamond Border X-ray Mai...         559.30
# 24  Vinyl Coated Wire Paper Clips in Organizer Box...         119.69
# 25                       Advantus Plastic Paper Clips         102.80
# 26                                            Staples          85.68
# 27  GE 48" Fluorescent Tube, Cool White Energy Sav...        1260.20
# 28  Electrix Architect's Clamp-On Swing Arm Lamp, ...         627.16
# 29  3M Polarizing Task Lamp with Clamp Arm, Light ...         569.80
# 30  Dot Matrix Printer Tape Reel Labels, White, 50...        1517.85
# 31  Avery 4027 File Folder Labels for Dot Matrix P...         524.44
# 32                                          Avery 485         300.30
# 33  HP Designjet T520 Inkjet Large Format Printer ...        4094.97
# 34                  Ativa V4110MDD Micro-Cut Shredder        3772.94
# 35   3D Systems Cube Printer, 2nd Generation, Magenta        3717.96
# 36                                         Xerox 1915        1262.34
# 37                 Multicolor Computer Printout Paper         851.36
# 38                                         Xerox 1908         799.38
# 39                            Samsung Galaxy Mega 6.3        1822.73
# 40                                     Apple iPhone 5        1611.56
# 41                               Panasonic KX-TG9471B        1168.06
# 42                     Hot File 7-Pocket, Floor Stand        2016.65
# 43                 Adjustable Depth Letter/Legal Cart        1932.51
# 44              Dual Level, Single-Width Filing Carts        1640.49
# 45              Acme 10" Easy Grip Assistive Scissors         129.67
# 46  Acme Hot Forged Carbon Steel Scissors with Nic...         103.38
# 47                          Fiskars Softgrip Scissors          86.05
# 48  SAFCO PlanMaster Heigh-Adjustable Drafting Tab...         608.04
# 49                     Hon Non-Folding Utility Tables         541.64
# 50      Bretford CR8500 Series Meeting Room Furniture         461.13
#
#     SubCategory  ProfitRank
# 0   Accessories           1
# 1   Accessories           2
# 2   Accessories           3
# 3    Appliances           1
# 4    Appliances           2
# 5    Appliances           3
# 6           Art           1
# 7           Art           2
# 8           Art           3
# 9       Binders           1
# 10      Binders           2
# 11      Binders           3
# 12    Bookcases           1
# 13    Bookcases           2
# 14    Bookcases           3
# 15       Chairs           1
# 16       Chairs           2
# 17       Chairs           3
# 18      Copiers           1
# 19      Copiers           2
# 20      Copiers           3
# 21    Envelopes           1
# 22    Envelopes           2
# 23    Envelopes           3
# 24    Fasteners           1
# 25    Fasteners           2
# 26    Fasteners           3
# 27  Furnishings           1
# 28  Furnishings           2
# 29  Furnishings           3
# 30       Labels           1
# 31       Labels           2
# 32       Labels           3
# 33     Machines           1
# 34     Machines           2
# 35     Machines           3
# 36        Paper           1
# 37        Paper           2
# 38        Paper           3
# 39       Phones           1
# 40       Phones           2
# 41       Phones           3
# 42      Storage           1
# 43      Storage           2
# 44      Storage           3
# 45     Supplies           1
# 46     Supplies           2
# 47     Supplies           3
# 48       Tables           1
# 49       Tables           2
# 50       Tables           3

# %%
# Count how many products overlap for each SubCategory?
pd.read_sql(
    """
    WITH SalesTable AS (
        SELECT *
        FROM (
            SELECT *,
                RANK() OVER (
                    PARTITION BY SubCategory
                    ORDER BY "SalesSum ($)" DESC
                ) AS SalesRank
            FROM (
                SELECT Products.ProductID, ProductName, SUM(Sales)/100.0 AS "SalesSum ($)", SubCategory
                FROM OrdersDetails
                JOIN Products ON OrdersDetails.ProductID = Products.ProductID
                GROUP BY Products.ProductID
            )
        )
        WHERE SalesRank <= 3
    ),
    ProfitTable AS (
        SELECT *
        FROM (
            SELECT *,
                RANK() OVER (
                    PARTITION BY SubCategory
                    ORDER BY "ProfitSum ($)" DESC
                ) AS ProfitRank
            FROM (
                SELECT Products.ProductID, ProductName, SUM(Profit)/100.0 AS "ProfitSum ($)", SubCategory
                FROM OrdersDetails
                JOIN Products ON OrdersDetails.ProductID = Products.ProductID
                GROUP BY Products.ProductID
            )
        )
        WHERE ProfitRank <= 3
    )

    -- Count the overlapping ProductIDs grouped by SubCategory
    SELECT ST.SubCategory,
        COUNT(ST.ProductID) AS OverlappingProductIDs
    FROM SalesTable ST
    INNER JOIN ProfitTable PT ON ST.ProductID = PT.ProductID
    GROUP BY ST.SubCategory;
    """, db_conn)
# Out:
#     SubCategory  OverlappingProductIDs
# 0   Accessories                      2
# 1    Appliances                      2
# 2           Art                      2
# 3       Binders                      1
# 4     Bookcases                      1
# 5       Copiers                      3
# 6     Envelopes                      2
# 7     Fasteners                      2
# 8   Furnishings                      1
# 9        Labels                      3
# 10     Machines                      1
# 11        Paper                      2
# 12       Phones                      2

# %%
# The products with the highest sales are mostly overlapping quite well with the products that bring the most profit.

# %%
# 4. What are the 3 best-seller products in each product segment? (Quantity-wise)
# Again, I assume by product segment, they mean SubCategory
# I use ROW_NUMBER() instead of RANK() or DENSE_Rank() to have only 3 items per SubCategory in the output in case of ties.
pd.read_sql(
    """
    SELECT ProductID, ProductName, QuantitySum, SubCategory
    FROM (
        SELECT *,
        ROW_NUMBER() OVER  (
            PARTITION BY SubCategory
            ORDER BY QuantitySum DESC
        ) AS row_num
        FROM
        (
            SELECT Products.ProductID, ProductName, SUM(Quantity) AS QuantitySum, SubCategory
            FROM OrdersDetails
            JOIN Products ON OrdersDetails.ProductID = Products.ProductID
            GROUP BY Products.ProductID
        )
    )
    WHERE row_num <= 3
    """, db_conn)
# Out:
#           ProductID                                        ProductName  \
# 0   TEC-AC-10003038         Kingston Digital DataTraveler 16GB USB 2.0
# 1   TEC-AC-10003628  Logitech 910-002974 M325 Wireless Mouse for We...
# 2   TEC-AC-10004510    Logitech Desktop MK120 Mouse and keyboard Combo
# 3   OFF-AP-10000358  Fellowes Basic Home/Office Series Surge Protec...
# 4   OFF-AP-10001492        Acco Six-Outlet Power Strip, 4' Cord Length
# 5   OFF-AP-10001205          Belkin 5 Outlet SurgeMaster Power Centers
# 6   OFF-AR-10004078                                         Newell 312
# 7   OFF-AR-10000380    Hunt PowerHouse Electric Pencil Sharpener, Blue
# 8   OFF-AR-10003514                       4009 Highlighters by Sanford
# 9   OFF-BI-10001524  GBC Premium Transparent Covers with Diagonal L...
# 10  OFF-BI-10004728  Wilson Jones Turn Tabs Binder Tool for Ring Bi...
# 11  OFF-BI-10003676  GBC Standard Recycled Report Covers, Clear Pla...
# 12  FUR-BO-10001972         O'Sullivan 4-Shelf Bookcase in Odessa Pine
# 13  FUR-BO-10002545  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...
# 14  FUR-BO-10004015   Bush Andora Bookcase, Maple/Graphite Gray Finish
# 15  FUR-CH-10002647         Situations Contoured Folding Chairs, 4/Set
# 16  FUR-CH-10003774    Global Wood Trimmed Manager's Task Chair, Khaki
# 17  FUR-CH-10002880          Global High-Back Leather Tilter, Burgundy
# 18  TEC-CO-10001449               Hewlett Packard LaserJet 3310 Copier
# 19  TEC-CO-10001943                       Canon PC-428 Personal Copier
# 20  TEC-CO-10002095  Hewlett Packard 610 Color Digital Copier / Pri...
# 21  OFF-EN-10001509                          Poly String Tie Envelopes
# 22  OFF-EN-10002600            Redi-Strip #10 Envelopes, 4 1/8 x 9 1/2
# 23  OFF-EN-10003286                                    Staple envelope
# 24  OFF-FA-10002280                       Advantus Plastic Paper Clips
# 25  OFF-FA-10000621           OIC Colored Binder Clips, Assorted Sizes
# 26  OFF-FA-10000624                                   OIC Binder Clips
# 27  FUR-FU-10004973                             Flat Face Poster Frame
# 28  FUR-FU-10000023                        Eldon Wave Desk Accessories
# 29  FUR-FU-10001706                       Longer-Life Soft White Bulbs
# 30  OFF-LA-10002762                                          Avery 485
# 31  OFF-LA-10001613                           Avery File Folder Labels
# 32  OFF-LA-10003510  Avery 4027 File Folder Labels for Dot Matrix P...
# 33  TEC-MA-10000822          Lexmark MX611dhe Monochrome Laser Printer
# 34  TEC-MA-10002428  Fellowes Powershred HS-440 4-Sheet High Securi...
# 35  TEC-MA-10000864                 Cisco 9971 IP Video Phone Charcoal
# 36  OFF-PA-10003441                                          Xerox 226
# 37  OFF-PA-10002986                                         Xerox 1898
# 38  OFF-PA-10000100                                         Xerox 1945
# 39  TEC-PH-10001552  I Need's 3d Hello Kitty Hybrid Silicone Case C...
# 40  TEC-PH-10003505                               Geemarc AmpliPOWER60
# 41  TEC-PH-10001557                                      Pyle PMP37LED
# 42  OFF-ST-10001809                  Fellowes Officeware Wire Shelving
# 43  OFF-ST-10000563        Fellowes Bankers Box Stor/Drawer Steel Plus
# 44  OFF-ST-10001490                     Hot File 7-Pocket, Floor Stand
# 45  OFF-SU-10000898  Acme Hot Forged Carbon Steel Scissors with Nic...
# 46  OFF-SU-10000381  Acme Forged Steel Scissors with Black Enamel H...
# 47  OFF-SU-10002537                           Acme Box Cutter Scissors
# 48  FUR-TA-10001095                 Chromcraft Round Conference Tables
# 49  FUR-TA-10001039                         KI Adjustable-Height Table
# 50  FUR-TA-10003473         Bretford Rectangular Conference Table Tops
#
#     QuantitySum  SubCategory
# 0            57  Accessories
# 1            52  Accessories
# 2            50  Accessories
# 3            41   Appliances
# 4            41   Appliances
# 5            40   Appliances
# 6            49          Art
# 7            44          Art
# 8            44          Art
# 9            67      Binders
# 10           59      Binders
# 11           51      Binders
# 12           37    Bookcases
# 13           35    Bookcases
# 14           34    Bookcases
# 15           64       Chairs
# 16           59       Chairs
# 17           54       Chairs
# 18           38      Copiers
# 19           25      Copiers
# 20           21      Copiers
# 21           35    Envelopes
# 22           35    Envelopes
# 23           35    Envelopes
# 24           47    Fasteners
# 25           44    Fasteners
# 26           38    Fasteners
# 27           51  Furnishings
# 28           45  Furnishings
# 29           44  Furnishings
# 30           51       Labels
# 31           44       Labels
# 32           43       Labels
# 33           18     Machines
# 34           17     Machines
# 35           16     Machines
# 36           53        Paper
# 37           46        Paper
# 38           45        Paper
# 39           52       Phones
# 40           46       Phones
# 41           43       Phones
# 42           55      Storage
# 43           50      Storage
# 44           49      Storage
# 45           36     Supplies
# 46           32     Supplies
# 47           31     Supplies
# 48           61       Tables
# 49           47       Tables
# 50           46       Tables

# %%
# 5. What are the top 3 worst-selling products in every category? (Quantity-wise)
pd.read_sql(
    """
    SELECT ProductID, ProductName, QuantitySum, Category
    FROM (
        SELECT *,
        ROW_NUMBER() OVER  (
            PARTITION BY Category
            ORDER BY QuantitySum
        ) AS row_num
        FROM
        (
            SELECT Products.ProductID, ProductName, SUM(Quantity) AS QuantitySum, Category
            FROM OrdersDetails
            JOIN Products ON OrdersDetails.ProductID = Products.ProductID
            GROUP BY Products.ProductID
        )
    )
    WHERE row_num <= 3
    """, db_conn)
# Out:
#          ProductID                                        ProductName  \
# 0  FUR-BO-10002206  Bush Saratoga Collection 5-Shelf Bookcase, Han...
# 1  FUR-CH-10002317  Global Enterprise Series Seating Low-Back Swiv...
# 2  FUR-FU-10002874      Ultra Commercial Grade Dual Valve Door Closer
# 3  OFF-AR-10002704              Boston 1900 Electric Pencil Sharpener
# 4  OFF-PA-10000048                                           Xerox 20
# 5  OFF-AP-10002203  Eureka Disposable Bags for Sanitaire Vibra Gro...
# 6  TEC-MA-10003493                Penpower WorldCard Pro Card Scanner
# 7  TEC-AC-10003133  Memorex Mini Travel Drive 4 GB USB 2.0 Flash D...
# 8  TEC-MA-10001856                              Okidata C610n Printer
#
#    QuantitySum         Category
# 0            1        Furniture
# 1            1        Furniture
# 2            2        Furniture
# 3            1  Office Supplies
# 4            1  Office Supplies
# 5            2  Office Supplies
# 6            1       Technology
# 7            2       Technology
# 8            2       Technology

# %%
# 6. How many unique customers per month are there for the year 2016.
# (There's a catch here: contrary to other 'heavier' RDBMS, SQLite does not support the functions YEAR() or MONTH() to extract the year or the month in a date.
# You will have to create two new columns: year and month.)
pd.read_sql(
    """
    SELECT Month, COUNT (DISTINCT CustomerID) AS CustomerCount
    FROM (
        SELECT
            *,
            SUBSTR(OrderDate, 1, 4) AS Year,
            SUBSTR(OrderDate, 6, 2) AS Month
        FROM Orders
    )
    WHERE Year = '2016'
    GROUP BY Month

    """, db_conn)
# Out:
#    Month  CustomerCount
# 0     01             46
# 1     02             42
# 2     03             80
# 3     04             83
# 4     05             96
# 5     06             90
# 6     07             89
# 7     08             86
# 8     09            176
# 9     10             95
# 10    11            165
# 11    12            157

# %%
# Close the db connection.
db_conn.close()
